# %% [markdown]
# # Complete CA CNN Classification Pipeline
#
# This notebook contains the complete pipeline for:
# 1. Data generation
# 2. Model training (5 models)
# 3. Evaluation and comparison
#
# **Note**: This will take several hours to complete. Consider running data generation and model training separately using notebooks 1 and 2.
#
# ## 실행 방법
#
# ### Google Colab에서 실행
# - 셀을 순서대로 실행 (환경 자동 감지)
# - GPU 사용 권장
#
# ### 로컬 환경에서 실행
# - 필요한 패키지 설치 후 실행
# - 환경 자동 감지됨

# %% [markdown]
# ## 🔧 Setup - Environment Detection

# %%
# 환경 감지 및 자동 설정
import sys
import os
from pathlib import Path

# Google Colab 환경 감지
try:
    import google.colab
    IN_COLAB = True
    print("🌐 Google Colab 환경 감지")
    
    # Google Drive 마운트
    print("\n💾 Google Drive 마운트 중...")
    from google.colab import drive
    drive.mount('/content/drive')
    
    # 데이터 경로 설정
    BASE_PATH = Path('/content/drive/MyDrive/Research/CA')
    
except ImportError:
    IN_COLAB = False
    print("💻 로컬 환경 감지")
    
    # 로컬 경로 설정
    current_dir = Path.cwd()
    
    # 현재 디렉토리에서 CA 폴더 찾기
    if 'CA' in str(current_dir):
        while current_dir.name != 'CA' and current_dir.parent != current_dir:
            current_dir = current_dir.parent
        BASE_PATH = current_dir
    else:
        # 기본 경로 사용
        BASE_PATH = Path('/Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA')
        if not BASE_PATH.exists():
            BASE_PATH = current_dir

# 경로 설정
DATA_DIR = BASE_PATH / 'Data'
MODEL_DIR = DATA_DIR / 'models'
CHECKPOINT_DIR = DATA_DIR / 'checkpoints'
DATA_FILE = DATA_DIR / 'data500_50.pickle'

# 디렉토리 생성
DATA_DIR.mkdir(parents=True, exist_ok=True)
MODEL_DIR.mkdir(parents=True, exist_ok=True)
CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)

print(f"\n📂 작업 경로: {BASE_PATH}")
print(f"📂 데이터 경로: {DATA_DIR}")
print(f"💾 데이터 파일: {DATA_FILE}")
print(f"\n환경: {'Colab' if IN_COLAB else 'Local'}")
# Out:
# 💻 로컬 환경 감지
#
# 📂 작업 경로: /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA
# 📂 데이터 경로: /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data
# 💾 데이터 파일: /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/data500_50.pickle
#
# 환경: Local

# %% [markdown]
# ## Import Libraries

# %%
import sys
import subprocess

# 필요한 패키지 자동 설치
def install_package(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", package])

# TensorFlow 설치 확인 및 설치
try:
    import tensorflow as tf
    print(f"✅ TensorFlow {tf.__version__} 로드 완료")
except ImportError:
    print("⚠️ TensorFlow를 찾을 수 없습니다. 설치를 시작합니다...")
    install_package("tensorflow")
    import tensorflow as tf
    print(f"✅ TensorFlow {tf.__version__} 설치 및 로드 완료")

# 나머지 라이브러리 import
import numpy as np
import numpy.random as rand
from tqdm import tqdm
import pickle
import matplotlib.pyplot as plt

from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from sklearn.model_selection import train_test_split

print(f"GPU 사용 가능: {len(tf.config.list_physical_devices('GPU')) > 0}")
print("✅ 라이브러리 로드 완료!")
# Out:
# ✅ TensorFlow 2.20.0 로드 완료
# GPU 사용 가능: False
# ✅ 라이브러리 로드 완료!

# %% [markdown]
# ## 📊 Part 1: Data Generation
#
# Generate training data by simulating Cellular Automata evolution.

# %%
# Set to True to generate new data, False to load existing
GENERATE_NEW_DATA = True  # 기존 데이터가 있으면 False로 설정

# %%
# Configuration - Method2 방식
# 76개 기본 규칙 (pad0)
labels_pad0 = [
    0, 40, 128, 136, 160,
    28, 50, 62, 94, 108, 156, 178,
    18, 22, 30, 60, 90, 122, 126, 146, 150, 182, 54, 110,
    238, 250, 254, 4, 12, 36, 44, 72, 76, 78, 104, 132, 140, 164, 200, 204, 206, 218, 222, 232, 236,
    6, 26, 38, 134, 154, 158, 166,
    2, 10, 24, 42, 46, 58, 74, 130, 138, 152, 162, 170, 174, 184, 186, 188, 190,
    234, 14, 168, 172, 202, 142, 106
]

# 홀수 규칙 추가 (pad1): 각 규칙에 +1
labels_pad1 = [i + 1 for i in labels_pad0]

# 전체 규칙: pad0 + pad1 = 152개
CA_RULES = labels_pad0 + labels_pad1
CA_RULES = [int(rule) for rule in CA_RULES]

# 제외할 규칙 (필요시 추가)
CA_0 = []  # 제외할 규칙이 있으면 여기에 추가

NUM_CLASSES = len(CA_RULES)
GRID_SIZE = 400
IMAGE_SIZE = 20
NUM_GENERATIONS = 20
NUM_SAMPLES_PER_RULE = 500
DENSITY_LEVELS = [1, 2, 3, 4, 5, 6]
CELLS_PER_DENSITY = 50

print(f"📊 설정 완료 (Method2)")
print(f"  - CA 룰 (pad0): {len(labels_pad0)}개")
print(f"  - CA 룰 (pad1): {len(labels_pad1)}개")
print(f"  - 총 CA 룰: {NUM_CLASSES}개")
print(f"  - 제외 규칙: {len(CA_0)}개")
print(f"  - 총 샘플: {(NUM_CLASSES - len(CA_0)) * NUM_SAMPLES_PER_RULE * len(DENSITY_LEVELS):,}개")
# Out:
# 📊 설정 완료 (Method2)
#   - CA 룰 (pad0): 76개
#   - CA 룰 (pad1): 76개
#   - 총 CA 룰: 152개
#   - 제외 규칙: 0개
#   - 총 샘플: 456,000개

# %%
# CA simulation functions - Method2 방식 (홀수/짝수 패딩 구분)

def get_wolfram_rule(rule_number):
    """
    Wolfram CA 규칙을 이진 매핑으로 변환
    """
    binary_rep = str(bin(rule_number))[2:]
    binary_rep = [0] * (8 - len(binary_rep)) + [int(b) for b in binary_rep]
    mapping = {
        (0,0,0): binary_rep[7], (0,0,1): binary_rep[6],
        (0,1,0): binary_rep[5], (0,1,1): binary_rep[4],
        (1,0,0): binary_rep[3], (1,0,1): binary_rep[2],
        (1,1,0): binary_rep[1], (1,1,1): binary_rep[0],
    }
    return mapping

def get_next_seq_pad0(previous_seq, rule_num):
    """
    짝수 규칙: 0으로 패딩
    """
    rule = get_wolfram_rule(rule_num)
    seq_length = len(previous_seq) - 2
    sub_seqs = [tuple(previous_seq[i:i + 3]) for i in range(seq_length)]
    new_seq = [rule[sub_seq] for sub_seq in sub_seqs]
    # 양 끝을 0으로 패딩
    new_seq.insert(0, 0)
    new_seq.append(0)
    return new_seq

def get_next_seq_pad1(previous_seq, rule_num):
    """
    홀수 규칙: 1로 패딩 (rule_num-1의 규칙 사용)
    """
    rule = get_wolfram_rule(rule_num - 1)
    seq_length = len(previous_seq) - 2
    sub_seqs = [tuple(previous_seq[i:i + 3]) for i in range(seq_length)]
    new_seq = [rule[sub_seq] for sub_seq in sub_seqs]
    # 양 끝을 1로 패딩
    new_seq.insert(0, 1)
    new_seq.append(1)
    return new_seq

def get_next_seq(previous_seq, rule_num):
    """
    규칙 번호에 따라 적절한 패딩 방식 선택
    짝수: pad0, 홀수: pad1
    """
    if rule_num % 2 == 0:
        return get_next_seq_pad0(previous_seq, rule_num)
    else:
        return get_next_seq_pad1(previous_seq, rule_num)

def rule_data20(start, rule_num):
    """
    정확히 20세대 진화
    """
    prev = start
    for _ in range(20):
        prev = get_next_seq(prev, rule_num)
    return prev

def generate_single_sample(rule_number, density_level, seed=None):
    """
    단일 샘플 생성 (Method2 방식)
    """
    if seed is not None:
        rand.seed(seed)
    
    # One-hot 인코딩
    y = np.zeros(NUM_CLASSES)
    y[CA_RULES.index(rule_number)] = 1
    
    # 초기 상태 생성
    num_active_cells = CELLS_PER_DENSITY * density_level
    idx = rand.choice(GRID_SIZE, num_active_cells, replace=False)
    initial_state = np.zeros(GRID_SIZE)
    initial_state[idx] = 1
    
    # 4개 시간대 진화
    gen_2030_seq = np.array(initial_state)
    gen_2050_seq = np.array(rule_data20(gen_2030_seq, rule_number))
    gen_2070_seq = np.array(rule_data20(gen_2050_seq, rule_number))
    gen_2090_seq = np.array(rule_data20(gen_2070_seq, rule_number))
    
    # 20x20 행렬로 변환
    gen_2030_mat = gen_2030_seq.reshape(IMAGE_SIZE, IMAGE_SIZE)
    gen_2050_mat = gen_2050_seq.reshape(IMAGE_SIZE, IMAGE_SIZE)
    gen_2070_mat = gen_2070_seq.reshape(IMAGE_SIZE, IMAGE_SIZE)
    gen_2090_mat = gen_2090_seq.reshape(IMAGE_SIZE, IMAGE_SIZE)
    
    # (4, 20, 20) 형태로 스택
    X = np.array([gen_2030_mat, gen_2050_mat, gen_2070_mat, gen_2090_mat])
    return X, y

print("✅ CA 시뮬레이션 함수 정의 완료! (Method2 - 홀수/짝수 패딩 구분)")
# Out:
# ✅ CA 시뮬레이션 함수 정의 완료! (Method2 - 홀수/짝수 패딩 구분)

# %%
if GENERATE_NEW_DATA:
    print("🔄 데이터 생성 시작... (Method2)")
    print("⏱️ 예상 시간: 약 30-40분\n")
    
    X_list = []
    y_list = []
    
    for rule in tqdm(CA_RULES, desc="Processing rules"):
        # CA_0에 포함된 규칙은 건너뛰기
        if rule in CA_0:
            continue
            
        for sample_idx in range(NUM_SAMPLES_PER_RULE):
            for density_level in DENSITY_LEVELS:
                seed = 500 * rule + sample_idx
                X_i, y_i = generate_single_sample(rule, density_level, seed=seed)
                X_list.append(X_i)
                y_list.append(y_i)
    
    X = np.array(X_list)
    y = np.array(y_list)
    X = np.transpose(X, (0, 2, 3, 1))
    
    print(f"\n✅ 데이터 생성 완료!")
    print(f"  X shape: {X.shape}")
    print(f"  y shape: {y.shape}")
    
    # Save data
    print(f"\n💾 데이터 저장 중: {DATA_FILE}")
    with open(DATA_FILE, 'wb') as f:
        pickle.dump((X, y), f, pickle.HIGHEST_PROTOCOL)
    print(f"✅ 데이터 저장 완료!")
else:
    print(f"📂 기존 데이터 로드: {DATA_FILE}")
    with open(DATA_FILE, 'rb') as f:
        X, y = pickle.load(f)
    print(f"✅ 데이터 로드 완료! X: {X.shape}, y: {y.shape}")
# Out:
# 🔄 데이터 생성 시작... (Method2)
# ⏱️ 예상 시간: 약 30-40분
# Processing rules: 100%|██████████| 152/152 [19:52<00:00,  7.84s/it]
# ✅ 데이터 생성 완료!
#   X shape: (456000, 20, 20, 4)
#   y shape: (456000, 152)
#
# 💾 데이터 저장 중: /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/data500_50.pickle
# ✅ 데이터 저장 완료!

# %% [markdown]
# ## 🧠 Part 2: Model Training
#
# Train 5 independent CNN models.

# %%
# Training Configuration
INPUT_SHAPE = (20, 20, 4)
BATCH_SIZE = 100
EPOCHS = 100
NUM_MODELS = 5
MODEL_SEEDS = [42, 123, 456, 789, 1011]

print(f"🎯 학습 설정")
print(f"  - 모델 개수: {NUM_MODELS}")
print(f"  - Epochs: {EPOCHS}")
print(f"  - Batch size: {BATCH_SIZE}")
# Out:
# 🎯 학습 설정
#   - 모델 개수: 5
#   - Epochs: 100
#   - Batch size: 100

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)
print(f"📊 데이터 분할")
print(f"  - Training: {len(X_train):,}")
print(f"  - Test: {len(X_test):,}")
# Out:
# 📊 데이터 분할
#   - Training: 364,800
#   - Test: 91,200

# %%
# Model building functions
def set_seed(seed):
    np.random.seed(seed)
    tf.random.set_seed(seed)

def build_cnn_model():
    model = models.Sequential([
        layers.InputLayer(input_shape=INPUT_SHAPE),
        layers.Conv2D(32, (3, 3), activation="relu", padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation="relu", padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation="relu"),
        layers.BatchNormalization(),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(NUM_CLASSES, activation="softmax")
    ])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

print("✅ 모델 빌드 함수 정의 완료!")
# Out:
# ✅ 모델 빌드 함수 정의 완료!

# %%
# Train all models
results = {}

print("🚀 모델 학습 시작...")
print(f"⏱️ 예상 시간: 약 2-3시간 (GPU 사용 시)\n")

for i in range(NUM_MODELS):
    model_idx = i + 1
    seed = MODEL_SEEDS[i]
    
    print(f"\n{'='*70}")
    print(f"🔵 Model {model_idx} / {NUM_MODELS} (seed={seed})")
    print(f"{'='*70}")
    
    set_seed(seed)
    model = build_cnn_model()
    
    checkpoint_path = str(CHECKPOINT_DIR / f"model_checkpoint_{model_idx}.weights.h5")
    callbacks = [
        ModelCheckpoint(checkpoint_path, save_weights_only=True, monitor='val_loss', 
                       mode='min', save_best_only=True, verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=0.00001, verbose=1),
        EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True, verbose=1)
    ]
    
    history = model.fit(
        X_train, y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_split=0.1,
        callbacks=callbacks,
        verbose=2
    )
    
    score = model.evaluate(X_test, y_test, verbose=0)
    print(f"\n📊 Test Accuracy: {score[1]:.4f}")
    print(f"📊 Test Loss: {score[0]:.4f}")
    
    model_path = str(MODEL_DIR / f"model_{model_idx}.keras")
    model.save(model_path)
    print(f"💾 Model saved: {model_path}")
    
    results[f"model_{model_idx}"] = {
        "test_accuracy": score[1],
        "test_loss": score[0],
        "seed": seed,
        "epochs_trained": len(history.history['loss'])
    }

print("\n" + "="*70)
print("🎉 모든 모델 학습 완료!")
print("="*70)
# Out:
# 🚀 모델 학습 시작...
# ⏱️ 예상 시간: 약 2-3시간 (GPU 사용 시)
#
#
# ======================================================================
# 🔵 Model 1 / 5 (seed=42)
# ======================================================================
# /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/sdm_env/lib/python3.11/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch 1/100
#
# Epoch 1: val_loss improved from None to 0.57844, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_1.weights.h5
# 3284/3284 - 75s - 23ms/step - accuracy: 0.6441 - loss: 0.9771 - val_accuracy: 0.7442 - val_loss: 0.5784 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.57844 to 0.44496, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_1.weights.h5
# 3284/3284 - 80s - 24ms/step - accuracy: 0.7679 - loss: 0.5100 - val_accuracy: 0.7879 - val_loss: 0.4450 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.44496 to 0.40396, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_1.weights.h5
# 3284/3284 - 84s - 25ms/step - accuracy: 0.7923 - loss: 0.4467 - val_accuracy: 0.8054 - val_loss: 0.4040 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.40396 to 0.39627, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_1.weights.h5
# 3284/3284 - 88s - 27ms/step - accuracy: 0.8057 - loss: 0.4117 - val_accuracy: 0.8109 - val_loss: 0.3963 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.39627 to 0.36490, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_1.weights.h5
# 3284/3284 - 88s - 27ms/step - accuracy: 0.8153 - loss: 0.3885 - val_accuracy: 0.8197 - val_loss: 0.3649 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.36490 to 0.36456, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_1.weights.h5
# 3284/3284 - 89s - 27ms/step - accuracy: 0.8240 - loss: 0.3701 - val_accuracy: 0.8228 - val_loss: 0.3646 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.36456 to 0.35114, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_1.weights.h5
# 3284/3284 - 89s - 27ms/step - accuracy: 0.8304 - loss: 0.3567 - val_accuracy: 0.8262 - val_loss: 0.3511 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.35114 to 0.34741, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_1.weights.h5
# 3284/3284 - 93s - 28ms/step - accuracy: 0.8348 - loss: 0.3464 - val_accuracy: 0.8274 - val_loss: 0.3474 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.34741 to 0.33947, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_1.weights.h5
# 3284/3284 - 91s - 28ms/step - accuracy: 0.8393 - loss: 0.3377 - val_accuracy: 0.8345 - val_loss: 0.3395 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.33947 to 0.32720, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_1.weights.h5
# 3284/3284 - 94s - 28ms/step - accuracy: 0.8427 - loss: 0.3309 - val_accuracy: 0.8372 - val_loss: 0.3272 - learning_rate: 0.0010
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.32720
# 3284/3284 - 98s - 30ms/step - accuracy: 0.8473 - loss: 0.3233 - val_accuracy: 0.8401 - val_loss: 0.3281 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.32720
# 3284/3284 - 99s - 30ms/step - accuracy: 0.8508 - loss: 0.3174 - val_accuracy: 0.8380 - val_loss: 0.3319 - learning_rate: 0.0010
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.32720 to 0.32321, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_1.weights.h5
# 3284/3284 - 103s - 31ms/step - accuracy: 0.8540 - loss: 0.3112 - val_accuracy: 0.8419 - val_loss: 0.3232 - learning_rate: 0.0010
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.32321
# 3284/3284 - 103s - 31ms/step - accuracy: 0.8569 - loss: 0.3062 - val_accuracy: 0.8394 - val_loss: 0.3261 - learning_rate: 0.0010
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.32321
# 3284/3284 - 100s - 30ms/step - accuracy: 0.8593 - loss: 0.3020 - val_accuracy: 0.8384 - val_loss: 0.3314 - learning_rate: 0.0010
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.32321
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3284/3284 - 96s - 29ms/step - accuracy: 0.8625 - loss: 0.2980 - val_accuracy: 0.8380 - val_loss: 0.3372 - learning_rate: 0.0010
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.32321 to 0.31549, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_1.weights.h5
# 3284/3284 - 96s - 29ms/step - accuracy: 0.8729 - loss: 0.2765 - val_accuracy: 0.8454 - val_loss: 0.3155 - learning_rate: 5.0000e-04
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.31549
# 3284/3284 - 98s - 30ms/step - accuracy: 0.8768 - loss: 0.2697 - val_accuracy: 0.8465 - val_loss: 0.3172 - learning_rate: 5.0000e-04
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.31549
# 3284/3284 - 100s - 30ms/step - accuracy: 0.8794 - loss: 0.2654 - val_accuracy: 0.8465 - val_loss: 0.3191 - learning_rate: 5.0000e-04
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.31549
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3284/3284 - 98s - 30ms/step - accuracy: 0.8810 - loss: 0.2616 - val_accuracy: 0.8433 - val_loss: 0.3289 - learning_rate: 5.0000e-04
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.31549
# 3284/3284 - 99s - 30ms/step - accuracy: 0.8876 - loss: 0.2507 - val_accuracy: 0.8481 - val_loss: 0.3170 - learning_rate: 2.5000e-04
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.31549
# 3284/3284 - 98s - 30ms/step - accuracy: 0.8902 - loss: 0.2469 - val_accuracy: 0.8464 - val_loss: 0.3197 - learning_rate: 2.5000e-04
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 17.
#
# 📊 Test Accuracy: 0.8467
# 📊 Test Loss: 0.3141
# 💾 Model saved: /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/models/model_1.keras
#
# ======================================================================
# 🔵 Model 2 / 5 (seed=123)
# ======================================================================
# Epoch 1/100
#
# Epoch 1: val_loss improved from None to 0.53952, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_2.weights.h5
# 3284/3284 - 100s - 30ms/step - accuracy: 0.6386 - loss: 0.9882 - val_accuracy: 0.7493 - val_loss: 0.5395 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.53952 to 0.47954, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_2.weights.h5
# 3284/3284 - 101s - 31ms/step - accuracy: 0.7718 - loss: 0.5052 - val_accuracy: 0.7753 - val_loss: 0.4795 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.47954 to 0.39773, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_2.weights.h5
# 3284/3284 - 98s - 30ms/step - accuracy: 0.7985 - loss: 0.4349 - val_accuracy: 0.8067 - val_loss: 0.3977 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.39773 to 0.36975, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_2.weights.h5
# 3284/3284 - 96s - 29ms/step - accuracy: 0.8116 - loss: 0.4005 - val_accuracy: 0.8178 - val_loss: 0.3697 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.36975
# 3284/3284 - 97s - 30ms/step - accuracy: 0.8207 - loss: 0.3771 - val_accuracy: 0.8154 - val_loss: 0.3728 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.36975 to 0.36513, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_2.weights.h5
# 3284/3284 - 95s - 29ms/step - accuracy: 0.8276 - loss: 0.3621 - val_accuracy: 0.8214 - val_loss: 0.3651 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.36513 to 0.35416, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_2.weights.h5
# 3284/3284 - 92s - 28ms/step - accuracy: 0.8328 - loss: 0.3501 - val_accuracy: 0.8272 - val_loss: 0.3542 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.35416 to 0.34135, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_2.weights.h5
# 3284/3284 - 91s - 28ms/step - accuracy: 0.8376 - loss: 0.3400 - val_accuracy: 0.8310 - val_loss: 0.3414 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.34135
# 3284/3284 - 90s - 27ms/step - accuracy: 0.8423 - loss: 0.3310 - val_accuracy: 0.8302 - val_loss: 0.3487 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.34135 to 0.33419, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_2.weights.h5
# 3284/3284 - 90s - 28ms/step - accuracy: 0.8460 - loss: 0.3242 - val_accuracy: 0.8343 - val_loss: 0.3342 - learning_rate: 0.0010
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.33419
# 3284/3284 - 93s - 28ms/step - accuracy: 0.8492 - loss: 0.3189 - val_accuracy: 0.8349 - val_loss: 0.3357 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.33419
# 3284/3284 - 91s - 28ms/step - accuracy: 0.8529 - loss: 0.3130 - val_accuracy: 0.8297 - val_loss: 0.3577 - learning_rate: 0.0010
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.33419 to 0.32735, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_2.weights.h5
# 3284/3284 - 96s - 29ms/step - accuracy: 0.8559 - loss: 0.3078 - val_accuracy: 0.8395 - val_loss: 0.3273 - learning_rate: 0.0010
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.32735
# 3284/3284 - 96s - 29ms/step - accuracy: 0.8581 - loss: 0.3038 - val_accuracy: 0.8362 - val_loss: 0.3364 - learning_rate: 0.0010
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.32735
# 3284/3284 - 95s - 29ms/step - accuracy: 0.8613 - loss: 0.2986 - val_accuracy: 0.8400 - val_loss: 0.3302 - learning_rate: 0.0010
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.32735
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3284/3284 - 92s - 28ms/step - accuracy: 0.8627 - loss: 0.2951 - val_accuracy: 0.8399 - val_loss: 0.3327 - learning_rate: 0.0010
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.32735 to 0.31614, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_2.weights.h5
# 3284/3284 - 93s - 28ms/step - accuracy: 0.8734 - loss: 0.2756 - val_accuracy: 0.8468 - val_loss: 0.3161 - learning_rate: 5.0000e-04
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.31614
# 3284/3284 - 95s - 29ms/step - accuracy: 0.8774 - loss: 0.2683 - val_accuracy: 0.8447 - val_loss: 0.3248 - learning_rate: 5.0000e-04
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.31614
# 3284/3284 - 98s - 30ms/step - accuracy: 0.8805 - loss: 0.2646 - val_accuracy: 0.8433 - val_loss: 0.3258 - learning_rate: 5.0000e-04
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.31614
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3284/3284 - 95s - 29ms/step - accuracy: 0.8820 - loss: 0.2610 - val_accuracy: 0.8470 - val_loss: 0.3201 - learning_rate: 5.0000e-04
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.31614
# 3284/3284 - 90s - 27ms/step - accuracy: 0.8887 - loss: 0.2498 - val_accuracy: 0.8476 - val_loss: 0.3174 - learning_rate: 2.5000e-04
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.31614
# 3284/3284 - 93s - 28ms/step - accuracy: 0.8903 - loss: 0.2463 - val_accuracy: 0.8476 - val_loss: 0.3189 - learning_rate: 2.5000e-04
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 17.
#
# 📊 Test Accuracy: 0.8472
# 📊 Test Loss: 0.3131
# 💾 Model saved: /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/models/model_2.keras
#
# ======================================================================
# 🔵 Model 3 / 5 (seed=456)
# ======================================================================
# Epoch 1/100
#
# Epoch 1: val_loss improved from None to 0.51033, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_3.weights.h5
# 3284/3284 - 92s - 28ms/step - accuracy: 0.6403 - loss: 0.9806 - val_accuracy: 0.7568 - val_loss: 0.5103 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.51033 to 0.44124, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_3.weights.h5
# 3284/3284 - 89s - 27ms/step - accuracy: 0.7677 - loss: 0.5103 - val_accuracy: 0.7893 - val_loss: 0.4412 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.44124 to 0.39096, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_3.weights.h5
# 3284/3284 - 92s - 28ms/step - accuracy: 0.7945 - loss: 0.4387 - val_accuracy: 0.8072 - val_loss: 0.3910 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.39096 to 0.38569, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_3.weights.h5
# 3284/3284 - 94s - 29ms/step - accuracy: 0.8110 - loss: 0.3976 - val_accuracy: 0.8109 - val_loss: 0.3857 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.38569 to 0.35209, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_3.weights.h5
# 3284/3284 - 88s - 27ms/step - accuracy: 0.8207 - loss: 0.3743 - val_accuracy: 0.8268 - val_loss: 0.3521 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.35209 to 0.34302, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_3.weights.h5
# 3284/3284 - 95s - 29ms/step - accuracy: 0.8274 - loss: 0.3581 - val_accuracy: 0.8288 - val_loss: 0.3430 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.34302 to 0.34168, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_3.weights.h5
# 3284/3284 - 92s - 28ms/step - accuracy: 0.8341 - loss: 0.3448 - val_accuracy: 0.8293 - val_loss: 0.3417 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.34168 to 0.33849, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_3.weights.h5
# 3284/3284 - 90s - 27ms/step - accuracy: 0.8390 - loss: 0.3346 - val_accuracy: 0.8345 - val_loss: 0.3385 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.33849
# 3284/3284 - 91s - 28ms/step - accuracy: 0.8443 - loss: 0.3257 - val_accuracy: 0.8315 - val_loss: 0.3439 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.33849 to 0.33368, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_3.weights.h5
# 3284/3284 - 87s - 27ms/step - accuracy: 0.8479 - loss: 0.3187 - val_accuracy: 0.8375 - val_loss: 0.3337 - learning_rate: 0.0010
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.33368 to 0.32729, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_3.weights.h5
# 3284/3284 - 89s - 27ms/step - accuracy: 0.8515 - loss: 0.3124 - val_accuracy: 0.8389 - val_loss: 0.3273 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.32729
# 3284/3284 - 91s - 28ms/step - accuracy: 0.8543 - loss: 0.3076 - val_accuracy: 0.8350 - val_loss: 0.3413 - learning_rate: 0.0010
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.32729 to 0.32354, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_3.weights.h5
# 3284/3284 - 89s - 27ms/step - accuracy: 0.8586 - loss: 0.3020 - val_accuracy: 0.8416 - val_loss: 0.3235 - learning_rate: 0.0010
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.32354 to 0.31588, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_3.weights.h5
# 3284/3284 - 90s - 28ms/step - accuracy: 0.8607 - loss: 0.2974 - val_accuracy: 0.8438 - val_loss: 0.3159 - learning_rate: 0.0010
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.31588
# 3284/3284 - 86s - 26ms/step - accuracy: 0.8625 - loss: 0.2938 - val_accuracy: 0.8373 - val_loss: 0.3326 - learning_rate: 0.0010
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.31588
# 3284/3284 - 86s - 26ms/step - accuracy: 0.8649 - loss: 0.2901 - val_accuracy: 0.8408 - val_loss: 0.3225 - learning_rate: 0.0010
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.31588
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3284/3284 - 88s - 27ms/step - accuracy: 0.8670 - loss: 0.2868 - val_accuracy: 0.8390 - val_loss: 0.3389 - learning_rate: 0.0010
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.31588 to 0.31342, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_3.weights.h5
# 3284/3284 - 89s - 27ms/step - accuracy: 0.8769 - loss: 0.2666 - val_accuracy: 0.8448 - val_loss: 0.3134 - learning_rate: 5.0000e-04
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.31342
# 3284/3284 - 92s - 28ms/step - accuracy: 0.8811 - loss: 0.2606 - val_accuracy: 0.8464 - val_loss: 0.3153 - learning_rate: 5.0000e-04
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.31342
# 3284/3284 - 91s - 28ms/step - accuracy: 0.8827 - loss: 0.2568 - val_accuracy: 0.8475 - val_loss: 0.3146 - learning_rate: 5.0000e-04
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.31342
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3284/3284 - 89s - 27ms/step - accuracy: 0.8846 - loss: 0.2542 - val_accuracy: 0.8473 - val_loss: 0.3180 - learning_rate: 5.0000e-04
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.31342
# 3284/3284 - 89s - 27ms/step - accuracy: 0.8911 - loss: 0.2431 - val_accuracy: 0.8494 - val_loss: 0.3140 - learning_rate: 2.5000e-04
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.31342
# 3284/3284 - 88s - 27ms/step - accuracy: 0.8928 - loss: 0.2399 - val_accuracy: 0.8501 - val_loss: 0.3134 - learning_rate: 2.5000e-04
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 18.
#
# 📊 Test Accuracy: 0.8480
# 📊 Test Loss: 0.3105
# 💾 Model saved: /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/models/model_3.keras
#
# ======================================================================
# 🔵 Model 4 / 5 (seed=789)
# ======================================================================
# Epoch 1/100
#
# Epoch 1: val_loss improved from None to 0.56261, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_4.weights.h5
# 3284/3284 - 87s - 27ms/step - accuracy: 0.6445 - loss: 0.9845 - val_accuracy: 0.7498 - val_loss: 0.5626 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.56261 to 0.50839, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_4.weights.h5
# 3284/3284 - 86s - 26ms/step - accuracy: 0.7754 - loss: 0.4985 - val_accuracy: 0.7730 - val_loss: 0.5084 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.50839 to 0.38628, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_4.weights.h5
# 3284/3284 - 86s - 26ms/step - accuracy: 0.8017 - loss: 0.4284 - val_accuracy: 0.8099 - val_loss: 0.3863 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.38628
# 3284/3284 - 87s - 27ms/step - accuracy: 0.8161 - loss: 0.3914 - val_accuracy: 0.8109 - val_loss: 0.3939 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.38628
# 3284/3284 - 86s - 26ms/step - accuracy: 0.8243 - loss: 0.3702 - val_accuracy: 0.8171 - val_loss: 0.3868 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.38628 to 0.36272, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_4.weights.h5
# 3284/3284 - 87s - 26ms/step - accuracy: 0.8310 - loss: 0.3554 - val_accuracy: 0.8236 - val_loss: 0.3627 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.36272 to 0.33926, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_4.weights.h5
# 3284/3284 - 88s - 27ms/step - accuracy: 0.8364 - loss: 0.3423 - val_accuracy: 0.8328 - val_loss: 0.3393 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.33926 to 0.32943, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_4.weights.h5
# 3284/3284 - 88s - 27ms/step - accuracy: 0.8414 - loss: 0.3327 - val_accuracy: 0.8368 - val_loss: 0.3294 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.32943
# 3284/3284 - 89s - 27ms/step - accuracy: 0.8450 - loss: 0.3258 - val_accuracy: 0.8351 - val_loss: 0.3336 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.32943 to 0.32367, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_4.weights.h5
# 3284/3284 - 88s - 27ms/step - accuracy: 0.8475 - loss: 0.3189 - val_accuracy: 0.8381 - val_loss: 0.3237 - learning_rate: 0.0010
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.32367
# 3284/3284 - 88s - 27ms/step - accuracy: 0.8512 - loss: 0.3133 - val_accuracy: 0.8396 - val_loss: 0.3257 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.32367 to 0.32201, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_4.weights.h5
# 3284/3284 - 88s - 27ms/step - accuracy: 0.8551 - loss: 0.3073 - val_accuracy: 0.8416 - val_loss: 0.3220 - learning_rate: 0.0010
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.32201
# 3284/3284 - 89s - 27ms/step - accuracy: 0.8575 - loss: 0.3029 - val_accuracy: 0.8408 - val_loss: 0.3264 - learning_rate: 0.0010
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.32201
# 3284/3284 - 91s - 28ms/step - accuracy: 0.8604 - loss: 0.2980 - val_accuracy: 0.8397 - val_loss: 0.3241 - learning_rate: 0.0010
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.32201
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3284/3284 - 89s - 27ms/step - accuracy: 0.8633 - loss: 0.2934 - val_accuracy: 0.8407 - val_loss: 0.3288 - learning_rate: 0.0010
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.32201 to 0.31341, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_4.weights.h5
# 3284/3284 - 92s - 28ms/step - accuracy: 0.8737 - loss: 0.2728 - val_accuracy: 0.8454 - val_loss: 0.3134 - learning_rate: 5.0000e-04
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.31341
# 3284/3284 - 87s - 26ms/step - accuracy: 0.8774 - loss: 0.2673 - val_accuracy: 0.8449 - val_loss: 0.3221 - learning_rate: 5.0000e-04
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.31341
# 3284/3284 - 82s - 25ms/step - accuracy: 0.8796 - loss: 0.2632 - val_accuracy: 0.8466 - val_loss: 0.3185 - learning_rate: 5.0000e-04
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.31341
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3284/3284 - 87s - 26ms/step - accuracy: 0.8818 - loss: 0.2601 - val_accuracy: 0.8467 - val_loss: 0.3245 - learning_rate: 5.0000e-04
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.31341
# 3284/3284 - 88s - 27ms/step - accuracy: 0.8882 - loss: 0.2480 - val_accuracy: 0.8485 - val_loss: 0.3160 - learning_rate: 2.5000e-04
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.31341
# 3284/3284 - 90s - 27ms/step - accuracy: 0.8904 - loss: 0.2446 - val_accuracy: 0.8475 - val_loss: 0.3212 - learning_rate: 2.5000e-04
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 16.
#
# 📊 Test Accuracy: 0.8470
# 📊 Test Loss: 0.3108
# 💾 Model saved: /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/models/model_4.keras
#
# ======================================================================
# 🔵 Model 5 / 5 (seed=1011)
# ======================================================================
# Epoch 1/100
#
# Epoch 1: val_loss improved from None to 0.51761, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_5.weights.h5
# 3284/3284 - 86s - 26ms/step - accuracy: 0.6277 - loss: 1.0292 - val_accuracy: 0.7607 - val_loss: 0.5176 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.51761 to 0.49167, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_5.weights.h5
# 3284/3284 - 86s - 26ms/step - accuracy: 0.7697 - loss: 0.5099 - val_accuracy: 0.7771 - val_loss: 0.4917 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.49167 to 0.44570, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_5.weights.h5
# 3284/3284 - 85s - 26ms/step - accuracy: 0.7944 - loss: 0.4428 - val_accuracy: 0.7881 - val_loss: 0.4457 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.44570 to 0.40596, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_5.weights.h5
# 3284/3284 - 87s - 27ms/step - accuracy: 0.8092 - loss: 0.4047 - val_accuracy: 0.8046 - val_loss: 0.4060 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.40596 to 0.37131, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_5.weights.h5
# 3284/3284 - 85s - 26ms/step - accuracy: 0.8181 - loss: 0.3819 - val_accuracy: 0.8194 - val_loss: 0.3713 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.37131 to 0.34986, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_5.weights.h5
# 3284/3284 - 85s - 26ms/step - accuracy: 0.8257 - loss: 0.3640 - val_accuracy: 0.8280 - val_loss: 0.3499 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.34986 to 0.34463, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_5.weights.h5
# 3284/3284 - 87s - 26ms/step - accuracy: 0.8320 - loss: 0.3505 - val_accuracy: 0.8282 - val_loss: 0.3446 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.34463
# 3284/3284 - 83s - 25ms/step - accuracy: 0.8365 - loss: 0.3401 - val_accuracy: 0.8226 - val_loss: 0.3648 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.34463 to 0.34180, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_5.weights.h5
# 3284/3284 - 85s - 26ms/step - accuracy: 0.8400 - loss: 0.3326 - val_accuracy: 0.8310 - val_loss: 0.3418 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.34180
# 3284/3284 - 86s - 26ms/step - accuracy: 0.8445 - loss: 0.3249 - val_accuracy: 0.8264 - val_loss: 0.3589 - learning_rate: 0.0010
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.34180 to 0.33645, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_5.weights.h5
# 3284/3284 - 86s - 26ms/step - accuracy: 0.8473 - loss: 0.3196 - val_accuracy: 0.8353 - val_loss: 0.3364 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.33645 to 0.33379, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_5.weights.h5
# 3284/3284 - 87s - 27ms/step - accuracy: 0.8504 - loss: 0.3147 - val_accuracy: 0.8351 - val_loss: 0.3338 - learning_rate: 0.0010
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.33379
# 3284/3284 - 87s - 27ms/step - accuracy: 0.8532 - loss: 0.3100 - val_accuracy: 0.8340 - val_loss: 0.3458 - learning_rate: 0.0010
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.33379
# 3284/3284 - 86s - 26ms/step - accuracy: 0.8554 - loss: 0.3053 - val_accuracy: 0.8330 - val_loss: 0.3427 - learning_rate: 0.0010
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.33379 to 0.32661, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_5.weights.h5
# 3284/3284 - 86s - 26ms/step - accuracy: 0.8580 - loss: 0.3012 - val_accuracy: 0.8393 - val_loss: 0.3266 - learning_rate: 0.0010
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.32661
# 3284/3284 - 84s - 26ms/step - accuracy: 0.8609 - loss: 0.2964 - val_accuracy: 0.8399 - val_loss: 0.3274 - learning_rate: 0.0010
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.32661 to 0.31992, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_5.weights.h5
# 3284/3284 - 86s - 26ms/step - accuracy: 0.8625 - loss: 0.2942 - val_accuracy: 0.8417 - val_loss: 0.3199 - learning_rate: 0.0010
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.31992
# 3284/3284 - 88s - 27ms/step - accuracy: 0.8642 - loss: 0.2911 - val_accuracy: 0.8402 - val_loss: 0.3264 - learning_rate: 0.0010
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.31992
# 3284/3284 - 86s - 26ms/step - accuracy: 0.8666 - loss: 0.2867 - val_accuracy: 0.8410 - val_loss: 0.3222 - learning_rate: 0.0010
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.31992
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3284/3284 - 85s - 26ms/step - accuracy: 0.8683 - loss: 0.2855 - val_accuracy: 0.8431 - val_loss: 0.3216 - learning_rate: 0.0010
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.31992 to 0.31730, saving model to /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/checkpoints/model_checkpoint_5.weights.h5
# 3284/3284 - 87s - 26ms/step - accuracy: 0.8779 - loss: 0.2658 - val_accuracy: 0.8446 - val_loss: 0.3173 - learning_rate: 5.0000e-04
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.31730
# 3284/3284 - 86s - 26ms/step - accuracy: 0.8809 - loss: 0.2606 - val_accuracy: 0.8453 - val_loss: 0.3186 - learning_rate: 5.0000e-04
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.31730
# 3284/3284 - 85s - 26ms/step - accuracy: 0.8835 - loss: 0.2570 - val_accuracy: 0.8453 - val_loss: 0.3185 - learning_rate: 5.0000e-04
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.31730
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3284/3284 - 83s - 25ms/step - accuracy: 0.8854 - loss: 0.2538 - val_accuracy: 0.8448 - val_loss: 0.3219 - learning_rate: 5.0000e-04
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.31730
# 3284/3284 - 85s - 26ms/step - accuracy: 0.8908 - loss: 0.2444 - val_accuracy: 0.8466 - val_loss: 0.3186 - learning_rate: 2.5000e-04
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.31730
# 3284/3284 - 85s - 26ms/step - accuracy: 0.8922 - loss: 0.2409 - val_accuracy: 0.8487 - val_loss: 0.3211 - learning_rate: 2.5000e-04
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 21.
#
# 📊 Test Accuracy: 0.8469
# 📊 Test Loss: 0.3137
# 💾 Model saved: /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/models/model_5.keras
#
# ======================================================================
# 🎉 모든 모델 학습 완료!
# ======================================================================

# %% [markdown]
# ## 📈 Part 3: Results Summary

# %%
print("\n📊 학습 결과 요약")
print("="*70)
for model_name, result in results.items():
    print(f"{model_name}:")
    print(f"  - Accuracy: {result['test_accuracy']:.4f}")
    print(f"  - Loss: {result['test_loss']:.4f}")
    print(f"  - Epochs: {result['epochs_trained']}")
    print(f"  - Seed: {result['seed']}")
    print()

avg_accuracy = np.mean([r['test_accuracy'] for r in results.values()])
avg_loss = np.mean([r['test_loss'] for r in results.values()])

print(f"평균 Test Accuracy: {avg_accuracy:.4f}")
print(f"평균 Test Loss: {avg_loss:.4f}")
# Out:
# 📊 학습 결과 요약
# ======================================================================
# model_1:
#   - Accuracy: 0.8467
#   - Loss: 0.3141
#   - Epochs: 22
#   - Seed: 42
#
# model_2:
#   - Accuracy: 0.8472
#   - Loss: 0.3131
#   - Epochs: 22
#   - Seed: 123
#
# model_3:
#   - Accuracy: 0.8480
#   - Loss: 0.3105
#   - Epochs: 23
#   - Seed: 456
#
# model_4:
#   - Accuracy: 0.8470
#   - Loss: 0.3108
#   - Epochs: 21
#   - Seed: 789
#
# model_5:
#   - Accuracy: 0.8469
#   - Loss: 0.3137
#   - Epochs: 26
#   - Seed: 1011
#
# 평균 Test Accuracy: 0.8472
# 평균 Test Loss: 0.3124

# %%
# Visualization
model_names = list(results.keys())
accuracies = [results[m]['test_accuracy'] for m in model_names]
losses = [results[m]['test_loss'] for m in model_names]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Accuracy comparison
ax1.bar(model_names, accuracies, color='skyblue', alpha=0.8)
ax1.set_ylabel('Test Accuracy', fontsize=12)
ax1.set_title('Model Comparison - Test Accuracy', fontsize=14, fontweight='bold')
ax1.set_ylim([min(accuracies) - 0.05, 1.0])
ax1.grid(True, alpha=0.3, axis='y')

# Loss comparison
ax2.bar(model_names, losses, color='salmon', alpha=0.8)
ax2.set_ylabel('Test Loss', fontsize=12)
ax2.set_title('Model Comparison - Test Loss', fontsize=14, fontweight='bold')
ax2.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
comparison_path = str(MODEL_DIR / 'model_comparison.png')
plt.savefig(comparison_path, dpi=150, bbox_inches='tight')
print(f"💾 비교 그래프 저장: {comparison_path}")
plt.show()

print("\n✅ 전체 파이프라인 완료!")
# Out:
# 💾 비교 그래프 저장: /Users/mkim/Library/CloudStorage/GoogleDrive-wuj2293@gmail.com/내 드라이브/Research/CA/Data/models/model_comparison.png
# ✅ 전체 파이프라인 완료!
