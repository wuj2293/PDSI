# %% [markdown]
# # LHS 샘플링 PDSI 계산

# %%
import numpy as np
import matplotlib.pyplot as plt
import openpyxl
import pandas as pd
import os
import tensorflow as tf
from tensorflow import keras
import pickle
import numpy.random as rand
import h5py
import time
from tqdm import tqdm
from pathlib import Path

# %%
base = Path.cwd().parents[3]
model_dir = [base / "PDSI_data" / "CA_128" / "models" / "model_1.keras", 
             base / "PDSI_data" / "CA_128" / "models" / "model_2.keras", 
             base / "PDSI_data" / "CA_128" / "models" / "model_3.keras", 
             base / "PDSI_data" / "CA_128" / "models" / "model_4.keras", 
             base / "PDSI_data" / "CA_128" / "models" / "model_5.keras"]
local_index = pd.read_csv(base / "PDSI_data" / "SDM_data" / "latin" / "local_index.csv")
local_name = local_index["SIG_ENG_NM"].tolist()

with open(base / "PDSI_data" / "SDM_data" / "latin" / "TES_maxent" / "all.pkl", 'rb') as file:
    local_all = pickle.load(file)
with open(base / "PDSI_data" / "SDM_data" / "latin" / "TES_maxent" / "sampling.pkl", 'rb') as file:
    local_lhs = pickle.load(file)
species_path = str(base / "PDSI_data" / "SDM_data" / "latin" / "TES_maxent") #분석하고 싶은 종 선택 (TES)
scenario = ['126', '126', '126', '126'] #시나리오 선택
seeed_num = 10

# %% [markdown]
# # 행정구역별 샘플링을 확인

# %%
for i, name in enumerate(local_name):
    print(f"{i}:{name}", end=" | ")
# Out:
# 0:Goseong-gun2 | 1:Inje-gun1 | 2:Cheorwon-gun | 3:Yanggu-gun | 4:Hwacheon-gun | 5:Yeoncheon-gun | 6:Sokcho-si | 7:Pocheon-si | 8:Yangyang-gun | 9:Chuncheon-si | 10:Gapyeong-gun | 11:Paju-si | 12:Ongjin-gun | 13:Dongducheon-si | 14:Hongcheon-gun | 15:Yangju-si | 16:Gangneung-si | 17:Ganghwa-gun | 18:Pyeongchang-gun | 19:Uijeongbu-si | 20:Namyangju-si | 21:Gimpo-si | 22:Goyang-si | 23:Seoul-si | 24:Hoengseong-gun | 25:Yangpyeong-gun | 26:Guri-si | 27:Incheon-si | 28:Donghae-si | 29:Hanam-si | 30:Jeongseon-gun | 31:Bucheon-si | 32:Gwangju-si2 | 33:Ulleung-gun | 34:Wonju-si | 35:Gwangmyeong-si | 36:Siheung-si | 37:Seongnam-si | 38:Samcheok-si | 39:Gwacheon-si | 40:Anyang-si | 41:Yeoju-si | 42:Uiwang-si | 43:Yeongwol-gun | 44:Gunpo-si | 45:Ansan-si | 46:Yongin-si | 47:Icheon-si | 48:Suwon-si | 49:Taebaek-si | 50:Hwaseong-si | 51:Jecheon-si | 52:Chungju-si | 53:Osan-si | 54:Anseong-si | 55:Eumseong-gun | 56:Danyang-gun | 57:Pyeongtaek-si | 58:Uljin-gun | 59:Bonghwa-gun | 60:Yeongju-si | 61:Dangjin-si | 62:Jincheon-gun | 63:Seosan-si | 64:Cheonan-si | 65:Taean-gun | 66:Goesan-gun | 67:Asan-si | 68:Yeongyang-gun | 69:Mungyeong-si | 70:Jeungpyeong-gun | 71:Yecheon-gun | 72:Andong-si | 73:Yesan-gun | 74:Cheongju-si | 75:Sejong-si | 76:Gongju-si | 77:Hongseong-gun | 78:Yeongdeok-gun | 79:Sangju-si | 80:Boeun-gun | 81:Cheongsong-gun | 82:Cheongyang-gun | 83:Uiseong-gun | 84:Boryeong-si | 85:Daejeon-si | 86:Okcheon-gun | 87:Buyeo-gun | 88:Gumi-si | 89:Gyeryong-si | 90:Nonsan-si | 91:Pohang-si | 92:Gunwi-gun | 93:Yeongdong-gun | 94:Geumsan-gun | 95:Gimcheon-si | 96:Seocheon-gun | 97:Yeongcheon-si | 98:Iksan-si | 99:Wanju-gun | 100:Gunsan-si | 101:Chilgok-gun | 102:Gyeongju-si | 103:Muju-gun | 104:Seongju-gun | 105:Jinan-gun | 106:Daegu-si | 107:Gyeongsan-si | 108:Dalseong-gun | 109:Gimje-si | 110:Geochang-gun | 111:Jeonju-si | 112:Goryeong-gun | 113:Cheongdo-gun | 114:Jangsu-gun | 115:Hapcheon-gun | 116:Buan-gun | 117:Imsil-gun | 118:Hamyang-gun | 119:Jeongeup-si | 120:Ulju-gun | 121:Changnyeong-gun | 122:Ulsan-si | 123:Miryang-si | 124:Gochang-gun | 125:Sancheong-gun | 126:Namwon-si | 127:Sunchang-gun | 128:Yangsan-si | 129:Uiryeong-gun | 130:Jangseong-gun | 131:Damyang-gun | 132:Yeonggwang-gun | 133:Haman-gun | 134:Gimhae-si | 135:Changwon-si | 136:Gijang-gun | 137:Gurye-gun | 138:Jinju-si | 139:Gokseong-gun | 140:Hadong-gun | 141:Busan-si | 142:Gwangju-si1 | 143:Hampyeong-gun | 144:Hwasun-gun | 145:Suncheon-si | 146:Gwangyang-si | 147:Sacheon-si | 148:Muan-gun | 149:Sinan-gun | 150:Goseong-gun1 | 151:Naju-si | 152:Geoje-si | 153:Boseong-gun | 154:Tongyeong-si | 155:Yeongam-gun | 156:Namhae-gun | 157:Yeosu-si | 158:Jangheung-gun | 159:Mokpo-si | 160:Goheung-gun | 161:Gangjin-gun | 162:Haenam-gun | 163:Jindo-gun | 164:Wando-gun | 165:Jeju-si | 166:Seogwipo-si |

# %%
# 분석하고 싶은 행정구역 선택
k = 20

print(local_name[k])
aa = local_all["ssp245_2050"][local_name[k]] #시나리오, 연도에 상관 없음
bb = local_lhs["ssp245_2050"][local_name[k]]

plt.scatter(aa['x'], aa['y'], color='lightblue', label='All Data', alpha=0.5)
plt.scatter(bb['x'], bb['y'], color='red', label='All Data', alpha=0.5)
# Out:
# Namyangju-si

# %% [markdown]
# ### 멕센트 데이터를 가져와 20by20의 행렬 데이터를 만드는 함수

# %%
#lhs
def make_maxent_mat(scenario, loc):
    maxent_mat = []
    for i in ["ssp"+str(scenario[0])+"_2030", "ssp"+str(scenario[1])+"_2050",
              "ssp"+str(scenario[2])+"_2070", "ssp"+str(scenario[3])+"_2090"]:
        dataF = local_lhs[i][loc]
        dataF = dataF.iloc[:,2]
        dataF = np.reshape(dataF,(20,20))
        maxent_mat.append(dataF)
        
    maxent_mat = np.array(maxent_mat)
    maxent_mat = np.transpose(maxent_mat,(1,2,0))
    maxent_mat = np.reshape(maxent_mat,(1,20,20,4))
    return maxent_mat

# %%
maxent_mat = make_maxent_mat(scenario, 'Namyangju-si')

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5))  # 1행 4열, 전체 그림 크기 조정

axes[0].imshow(maxent_mat[0,:,:,0], cmap="gray")
axes[0].set_title('2030')

axes[1].imshow(maxent_mat[0,:,:,1], cmap="gray")
axes[1].set_title('2050')

axes[2].imshow(maxent_mat[0,:,:,2], cmap="gray")
axes[2].set_title('2070')

axes[3].imshow(maxent_mat[0,:,:,3], cmap="gray")
axes[3].set_title('2090')

fig.suptitle("20 by 20 maxent matrix")
plt.show()

# %% [markdown]
# ### 멕센트로 만든 20by20 행렬의 확률 값을 바이너리로 바꾸는 함수

# %%
# 맥센트 확률분포 바이너리화
def get_binary_maxent_mat(maxent_mat):
    a = np.random.rand(1, 20, 20, 4) # 1, 20, 20, 4 크기의 랜덤 행렬 생성
    binary_maxent_mat = (a < maxent_mat).astype(int) # maxent_mat와 비교하여 조건을 만족하는 곳에 1을 할당
    return binary_maxent_mat

# %% [markdown]
# ### 멕센트 데이터와 바이너리화 비교

# %%
def binary_maxent_mat_500(maxent_mat):
    Bmm = np.zeros((1,20,20,4))
    for e in range(500):
        binary_maxent_mat = np.array(get_binary_maxent_mat(maxent_mat), dtype=np.float32) 
        Bmm += binary_maxent_mat
    Bmm = Bmm/500
    
    return Bmm

# %%
Bmm = binary_maxent_mat_500(maxent_mat)

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5))  # 1행 4열, 전체 그림 크기 조정

axes[0].imshow(Bmm[0,:,:,0], cmap="gray")
axes[0].set_title('2030')

axes[1].imshow(Bmm[0,:,:,1], cmap="gray")
axes[1].set_title('2050')

axes[2].imshow(Bmm[0,:,:,2], cmap="gray")
axes[2].set_title('2070')

axes[3].imshow(Bmm[0,:,:,3], cmap="gray")
axes[3].set_title('2090')

fig.suptitle("Average of 500 binary matrices")
plt.show()

# %%
diff = maxent_mat - Bmm

fig, axes = plt.subplots(1, 4, figsize=(20, 5))  # 1행 4열, 전체 그림 크기 조정

axes[0].imshow(diff[0,:,:,0], cmap="RdBu_r", vmin=-1, vmax=1)
axes[0].set_title('2030')

axes[1].imshow(diff[0,:,:,1], cmap="RdBu_r", vmin=-1, vmax=1)
axes[1].set_title('2050')

axes[2].imshow(diff[0,:,:,2], cmap="RdBu_r", vmin=-1, vmax=1)
axes[2].set_title('2070')

axes[3].imshow(diff[0,:,:,3], cmap="RdBu_r", vmin=-1, vmax=1)
axes[3].set_title('2090')

fig.suptitle("difference")
plt.show()

# %% [markdown]
# ### CA_distribution 구하기

# %%
def make_CA_distribution(maxent_mat, model):
    # distribution 구하기
    b = np.zeros((1, int(model)), dtype=np.float32)
    initial = 0
    # 500회 반복 시행
    for direc in model_dir:
        model_call = keras.models.load_model(direc)
        for e in range(100):
            binary_maxent_mat = np.array(get_binary_maxent_mat(maxent_mat), dtype=np.float32) 
            initial += np.sum(binary_maxent_mat[:,:,:,0])
            model_output = model_call(binary_maxent_mat)
            model_output = np.array(model_output, dtype=np.float32)
            b += model_output
    CA_distribution = b/500
    initial = int(initial/500)
    
    return initial, CA_distribution

# %%
initial, CA_distribution = make_CA_distribution(maxent_mat, 128)

# %%
labels = list(range(0,256,2))

# %%
fig, axes = plt.subplots(1, 2) #, figsize=(12, 6))  # 1행 2열의 서브플롯 생성 (가로로 배치)

data = CA_distribution[0]

# 일반적인 원그래프
axes[0].pie(data, labels=labels ,autopct='%.1f%%', startangle=90, counterclock=False)

# 상위만 그린 원그래프
# 데이터와 레이블을 내림차순으로 정렬
sorted_indices = np.argsort(data)[::-1]
sorted_data = data[sorted_indices]
sorted_labels = np.array(labels)[sorted_indices]

# 상위 5개 항목만 선택
top_n = 4
top_data = sorted_data[:top_n]
top_labels = sorted_labels[:top_n]

# 나머지 항목을 "기타"로 처리
other_data = np.sum(sorted_data[top_n:])
other_label = 'Others'

# "기타" 항목 추가
final_data = np.append(top_data, other_data)
final_labels = np.append(top_labels, other_label)

# 파이 차트 그리기
axes[1].pie(final_data, labels=final_labels, autopct='%.1f%%', startangle=90, counterclock=False)

plt.tight_layout()  # 레이아웃 조정
plt.show()

# %% [markdown]
# ### SI 구하기

# %%
weight = np.load(base / "PDSI_data" / "weights" / "WeightByInitial.npy", allow_pickle=True)

# %%
def clu_SI(initial, CA_distribution):
    global weight, labels
    SI = 0
    for k, i in enumerate(labels):  # k는 인덱스, i는 labels의 값
        si = CA_distribution[0][k] * weight[i][initial]  # 각 원소를 선택하여 저장
        SI += si
        
    # # 전체 면적으로 나눌 때    
    SI = SI/400
    # # 초기갑으로 나눌 때
    # if initial != 0:
    #     SI = SI / initial
    # else:
    #     SI = 0
    
    return SI

# %%
clu_SI(initial, CA_distribution)
# Out:
# 0.6641572170380863

# %% [markdown]
# ### 모든 시나리오 별 각 행정구역의 값 계산

# %%
scenarios = [['126','126','126','126'],['126','126','126','245'],['126','126','126','585'],['126','126','245','126'],['126','126','245','245'],['126','126','245','585'],['126','126','585','126'],['126','126','585','245'],['126','126','585','585'],
             ['126','245','126','126'],['126','245','126','245'],['126','245','126','585'],['126','245','245','126'],['126','245','245','245'],['126','245','245','585'],['126','245','585','126'],['126','245','585','245'],['126','245','585','585'],
             ['126','585','126','126'],['126','585','126','245'],['126','585','126','585'],['126','585','245','126'],['126','585','245','245'],['126','585','245','585'],['126','585','585','126'],['126','585','585','245'],['126','585','585','585'],
             ['245','126','126','126'],['245','126','126','245'],['245','126','126','585'],['245','126','245','126'],['245','126','245','245'],['245','126','245','585'],['245','126','585','126'],['245','126','585','245'],['245','126','585','585'],
             ['245','245','126','126'],['245','245','126','245'],['245','245','126','585'],['245','245','245','126'],['245','245','245','245'],['245','245','245','585'],['245','245','585','126'],['245','245','585','245'],['245','245','585','585'],
             ['245','585','126','126'],['245','585','126','245'],['245','585','126','585'],['245','585','245','126'],['245','585','245','245'],['245','585','245','585'],['245','585','585','126'],['245','585','585','245'],['245','585','585','585'],
             ['585','126','126','126'],['585','126','126','245'],['585','126','126','585'],['585','126','245','126'],['585','126','245','245'],['585','126','245','585'],['585','126','585','126'],['585','126','585','245'],['585','126','585','585'],
             ['585','245','126','126'],['585','245','126','245'],['585','245','126','585'],['585','245','245','126'],['585','245','245','245'],['585','245','245','585'],['585','245','585','126'],['585','245','585','245'],['585','245','585','585'],
             ['585','585','126','126'],['585','585','126','245'],['585','585','126','585'],['585','585','245','126'],['585','585','245','245'],['585','585','245','585'],['585','585','585','126'],['585','585','585','245'],['585','585','585','585']]

# %%
# 시나리오별 처리 함수 정의
def process_scenario(scenario, base, local_name):
    # 파일을 추가 모드로 열기
    with h5py.File(base / "PDSI_data" / "Results" / "128_lhs.h5", 'a') as f:
        scenario_name = str(scenario[0])+'_'+str(scenario[1])+'_'+str(scenario[2])+'_'+str(scenario[3])
        # 이미 처리된 시나리오인지 확인
        if scenario_name in f:
            print(f"시나리오 {scenario_name}은 이미 처리되었습니다. 건너뜁니다.")
            return
        # 새 시나리오 그룹 생성
        scenario_group = f.create_group(f'{scenario_name}')
        # 이 시나리오의 모든 지역 처리
        for loc in local_name:
            maxent_mat = make_maxent_mat(scenario, loc)
            initial, CA_distribution = make_CA_distribution(maxent_mat, 128)
            SI = clu_SI(initial, CA_distribution)
            # 각 행정구역별 하위그룹 생성
            loc_group = scenario_group.create_group(f'{loc}')
            loc_group.create_dataset('initial', data=initial)
            loc_group.create_dataset('CA_distribution', data=CA_distribution)
            loc_group.create_dataset('SI', data=SI)
        print(f"시나리오 {scenario_name} 완료 및 저장됨")

# %%
# 파일이 없으면 새로 생성
import os
if not os.path.exists(base / "PDSI_data" / "Results" / "128_lhs.h5"):
    with h5py.File(str(base / "PDSI_data" / "Results" / "128_lhs.h5"), 'w') as f:
        pass  # 빈 파일 생성|
# 모든 시나리오 처리
for scenario in tqdm(scenarios, desc="전체 시나리오 처리 중"):
    process_scenario(scenario, base, local_name)
# Out:
# 전체 시나리오 처리 중:   0%|          | 0/81 [00:00<?, ?it/s]
# 시나리오 126_126_126_126은 이미 처리되었습니다. 건너뜁니다.
# 전체 시나리오 처리 중:   1%|          | 1/81 [01:08<1:31:19, 68.49s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/l1/0tg096d932nctcfhkkl1yrp80000gn/T/ipykernel_6259/3674245659.py in ?()
#       4     with h5py.File(str(base / "PDSI_data" / "Results" / "76_lhs.h5"), 'w') as f:
#       5         pass  # 빈 파일 생성|
#       6 # 모든 시나리오 처리
#       7 for scenario in tqdm(scenarios, desc="전체 시나리오 처리 중"):
# ----> 8     process_scenario(scenario, base, local_name)
#
# /var/folders/l1/0tg096d932nctcfhkkl1yrp80000gn/T/ipykernel_6259/2001852677.py in ?(scenario, base, local_name)
#      11         scenario_group = f.create_group(f'{scenario_name}')
#      12         # 이 시나리오의 모든 지역 처리
#      13         for loc in local_name:
#      14             maxent_mat = make_maxent_mat(scenario, loc)
# ---> 15             initial, CA_distribution = make_CA_distribution(maxent_mat, 76)
#      16             SI = clu_SI(initial, CA_distribution)
#      17             # 각 행정구역별 하위그룹 생성
#      18             loc_group = scenario_group.create_group(f'{loc}')
#
# /var/folders/l1/0tg096d932nctcfhkkl1yrp80000gn/T/ipykernel_6259/3038816460.py in ?(maxent_mat, model)
#       7         model_call = keras.models.load_model(direc)
#       8         for e in range(100):
#       9             binary_maxent_mat = np.array(get_binary_maxent_mat(maxent_mat), dtype=np.float32)
#      10             initial += np.sum(binary_maxent_mat[:,:,:,0])
# ---> 11             model_output = model_call(binary_maxent_mat)
#      12             model_output = np.array(model_output, dtype=np.float32)
#      13             b += model_output
#      14     CA_distribution = b/500
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/layer.py in ?(self, *args, **kwargs)
#     975                     "layers will not see the mask."
#     976                 )
#     977         finally:
#     978             # Destroy call context if we created it
# --> 979             self._maybe_reset_call_context()
#     980
#     981         ################################################
#     982         # 8. Add a node in the graph for symbolic calls.
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/ops/operation.py in ?(self, *args, **kwargs)
#      55             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56                 call_fn,
#      57                 object_name=(f"{self.__class__.__name__}.call()"),
#      58             )
# ---> 59             return call_fn(*args, **kwargs)
#      60
#      61         # Plain flow.
#      62         if any_symbolic_tensors(args, kwargs):
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/models/sequential.py in ?(self, inputs, training, mask, **kwargs)
#     218     def call(self, inputs, training=None, mask=None, **kwargs):
#     219         if self._functional:
# --> 220             return self._functional.call(
#     221                 inputs, training=training, mask=mask, **kwargs
#     222             )
#     223
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/models/functional.py in ?(self, inputs, training, mask, **kwargs)
#     179             masks = tree.flatten(mask)
#     180             for x, mask in zip(inputs, masks):
#     181                 if mask is not None:
#     182                     backend.set_keras_mask(x, mask)
# --> 183         outputs = self._run_through_graph(
#     184             inputs,
#     185             operation_fn=lambda op: operation_fn(
#     186                 op, training=training, **kwargs
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/ops/function.py in ?(self, inputs, operation_fn, call_fn)
#     202                 else:
#     203                     # Use NNX operation mapping
#     204                     operation = self._get_operation_for_node(node)
#     205                     op = operation_fn(operation)
# --> 206                     outputs = op(*args, **kwargs)
#     207
#     208                 # Update tensor_dict.
#     209                 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/models/functional.py in ?(*args, **kwargs)
#     640                 and value is not None
#     641             ):
#     642                 kwargs[name] = value
#     643
# --> 644         return operation(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/layer.py in ?(self, *args, **kwargs)
#     975                     "layers will not see the mask."
#     976                 )
#     977         finally:
#     978             # Destroy call context if we created it
# --> 979             self._maybe_reset_call_context()
#     980
#     981         ################################################
#     982         # 8. Add a node in the graph for symbolic calls.
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/ops/operation.py in ?(self, *args, **kwargs)
#      55             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56                 call_fn,
#      57                 object_name=(f"{self.__class__.__name__}.call()"),
#      58             )
# ---> 59             return call_fn(*args, **kwargs)
#      60
#      61         # Plain flow.
#      62         if any_symbolic_tensors(args, kwargs):
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/normalization/batch_normalization.py in ?(self, inputs, training, mask)
#     273             beta = ops.cast(self.beta, inputs.dtype)
#     274         else:
#     275             beta = None
#     276
# --> 277         outputs = ops.batch_normalization(
#     278             x=inputs,
#     279             mean=mean,
#     280             variance=variance,
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/ops/nn.py in ?(x, mean, variance, axis, offset, scale, epsilon)
#    2271         return BatchNorm(axis, epsilon).symbolic_call(
#    2272             x, mean, variance, offset, scale
#    2273         )
#    2274
# -> 2275     return backend.nn.batch_normalization(
#    2276         x, mean, variance, axis, offset, scale, epsilon
#    2277     )
#
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/nn.py in ?(x, mean, variance, axis, offset, scale, epsilon)
#     875             offset = tf.reshape(offset, shape)
#     876         if scale is not None:
#     877             scale = tf.reshape(scale, shape)
#     878
# --> 879     return tf.nn.batch_normalization(
#     880         x=x,
#     881         mean=mean,
#     882         variance=variance,
#
# /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/ops/nn_impl.py in ?(x, mean, variance, offset, scale, variance_epsilon, name)
#    1478       [Ioffe et al., 2015](http://arxiv.org/abs/1502.03167)
#    1479       ([pdf](http://proceedings.mlr.press/v37/ioffe15.pdf))
#    1480   """
#    1481   with ops.name_scope(name, "batchnorm", [x, mean, variance, scale, offset]):
# -> 1482     inv = math_ops.rsqrt(variance + variance_epsilon)
#    1483     if scale is not None:
#    1484       inv *= scale
#    1485     # Note: tensorflow/contrib/quantize/python/fold_batch_norms.py depends on
#
# /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/ops/weak_tensor_ops.py in ?(*args, **kwargs)
#      86   def wrapper(*args, **kwargs):
#      87     if not ops.is_auto_dtype_conversion_enabled():
# ---> 88       return op(*args, **kwargs)
#      89     bound_arguments = signature.bind(*args, **kwargs)
#      90     bound_arguments.apply_defaults()
#      91     bound_kwargs = bound_arguments.arguments
#
# /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/ops/math_ops.py in ?(x, name)
#    5834
#    5835   Returns:
#    5836     A `tf.Tensor`. Has the same type as `x`.
#    5837   """
# -> 5838   return gen_math_ops.rsqrt(x, name)
#
# /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/ops/gen_math_ops.py in ?(x, name)
#    8898         _ctx, "Rsqrt", name, x)
#    8899       return _result
#    8900     except _core._NotOkStatusException as e:
#    8901       _ops.raise_from_not_ok_status(e, name)
# -> 8902     except _core._FallbackException:
#    8903       pass
#    8904     try:
#    8905       return rsqrt_eager_fallback(
#
# KeyboardInterrupt:

# %%
# 데이터가 잘 만들어서 저장되어 있는지 확인합니다.
with h5py.File(str(base / "PDSI_data" / "Results" / "128_lhs.h5"), 'r') as f:
    # 그룹에 접근
    inje_group = f['585_585_585_585']['Inje-gun1']
    # 각 데이터셋 접근
    ca_distribution = inje_group['CA_distribution'][()]
    si_data = inje_group['SI'][()]
    initial_data = inje_group['initial'][()]
    
    # 데이터 확인
    print("CA_distribution 데이터:", ca_distribution.shape)
    print(ca_distribution)
    print("\nSI 데이터:")
    print(si_data)
    print("\ninitial 데이터:")
    print(initial_data)
# Out:
# CA_distribution 데이터: (1, 128)
# [[1.4004273e-12 1.3984296e-10 3.7128194e-09 3.5707882e-05 6.6263581e-08
#   1.3471026e-06 5.5485152e-08 8.3712017e-05 6.1475612e-12 3.8094096e-02
#   8.6095417e-05 6.2352163e-01 5.4842116e-07 4.4116024e-03 2.8618305e-07
#   9.9758524e-04 6.9998123e-08 1.7380400e-10 1.7838818e-08 7.1288717e-08
#   6.6181009e-08 9.0959835e-09 2.1483047e-06 2.3514302e-07 4.6762919e-12
#   2.5421429e-07 3.6020751e-08 1.7375016e-03 2.8750614e-07 1.5409500e-09
#   2.3407379e-02 1.1539018e-08 6.7447161e-08 3.0483423e-07 2.0099930e-04
#   2.9627557e-07 1.1997628e-09 7.7548080e-05 9.5311997e-08 2.9272751e-10
#   1.1268415e-06 3.0984592e-03 5.2216132e-05 5.3904387e-05 3.1621177e-05
#   1.7413373e-01 5.5791105e-09 3.1576391e-07 6.9522628e-08 3.3894858e-07
#   4.0953184e-04 2.6235621e-02 3.0906826e-09 3.1226594e-03 5.3176072e-06
#   1.0525364e-04 1.1280654e-09 4.4696327e-09 2.5374097e-06 1.7761401e-08
#   7.6847890e-04 8.2211562e-07 7.5011274e-05 4.4703080e-07 7.2513338e-08
#   1.9452397e-08 9.1868721e-08 4.4143404e-04 7.0682269e-08 3.6246870e-06
#   4.0132949e-08 2.2710321e-05 1.4058912e-10 4.3990608e-02 5.3208740e-04
#   5.1721610e-02 7.9802197e-07 1.0496288e-03 1.4924919e-06 8.3772012e-09
#   6.8766617e-08 3.9522594e-10 1.2430588e-07 2.0227157e-08 6.3089388e-08
#   1.5473964e-10 6.6194175e-08 5.0726195e-10 4.5611863e-08 1.6366764e-07
#   4.0946477e-09 7.9957374e-09 2.4512528e-07 1.7035918e-11 1.1331202e-08
#   7.0438266e-10 1.2674087e-12 6.6993193e-06 1.6549135e-04 5.7390203e-06
#   2.6656397e-09 4.5876480e-09 1.1598327e-08 3.1793741e-12 4.9204282e-06
#   1.2769017e-03 1.0022592e-06 7.0856176e-10 6.6805397e-09 4.9203850e-09
#   1.5097690e-10 9.5495507e-11 7.0764074e-08 1.9546917e-07 1.5783055e-05
#   8.7858130e-11 1.1078283e-08 3.2320600e-09 4.9164002e-09 6.0371091e-10
#   6.8517532e-11 1.2427040e-10 1.9762374e-10 1.8310707e-10 7.9116813e-10
#   3.8751782e-10 2.7160377e-10 2.6260524e-10]]
#
# SI 데이터:
# 0.2989204230601857
#
# initial 데이터:
# 20

# %%
#SI 데이터만 추출하여 저장합니다.
with h5py.File(str(base / "PDSI_data" / "Results" / "128_lhs.h5"), 'r') as f:
    # 최상위 키(시나리오 목록) 가져오기
    scenarios = list(f.keys())
    locs = list(f[scenarios[0]].keys())
    df = pd.DataFrame(index=locs, columns=scenarios)
    for scenario in scenarios:
        for loc in locs:
            df.loc[loc, scenario] = f[scenario][loc]['SI'][()]
df.to_csv(str(base / "PDSI_data" / "Results" / "128_lhs.csv"))
